# %%
! pip install dlib
# Out:
# Requirement already satisfied: dlib in c:\users\smt051\anaconda3\envs\pj3\lib\site-packages (19.21.1)

# %%
import dlib
import cv2
import numpy as np

# create list for landmarks
ALL = list(range(0, 68))
RIGHT_EYEBROW = list(range(17, 22))
LEFT_EYEBROW = list(range(22, 27))
RIGHT_EYE = list(range(36, 42))
LEFT_EYE = list(range(42, 48))
NOSE = list(range(27, 36))
MOUTH_OUTLINE = list(range(48, 61))
MOUTH_INNER = list(range(61, 68))
JAWLINE = list(range(0, 17))


# create face detector, predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

# %%
def md():
    import os
    co=0
    try:
        os.mkdir("C:/Users/SMT051/Desktop/nonono")
    except:
        print("이미 폴더가 있습니다.")
    # create VideoCapture object (input the video)
    # 0 for web camera
    vid_in = cv2.VideoCapture(0)
    # "---" for the video file
    #vid_in = cv2.VideoCapture("baby_vid.mp4")

    # capture the image in an infinite loop
    # -> make it looks like a video

    faceCheck = 0
    idx = 0
    while True:
        
        
        # get success : ret = True / fail : ret= False
        ret, image_o = vid_in.read()

       # resize the video
        image = cv2.resize(image_o, dsize=(640, 480), interpolation=cv2.INTER_AREA)
        img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Get faces (up-sampling=1)
        face_detector = detector(img_gray, 1)
        # the number of face detected

        if len(face_detector) == 0:
            faceCheck = 0
        else:
            faceCheck += 1
    #    print("The number of faces detected : {}".format(len(face_detector)))

        # loop as the number of face
        # one loop belong to one face

        if faceCheck > 60:
            print("마스크 !!!!! !!!경고 !!!!!")
            faceCheck=0
            co += 1
            cv2.imwrite("C:/Users/SMT051/Desktop/nonono/{}.png".format(co),image_o)


            #cv2.imwrite("C:/Users/SMT051/Desktop/마스크 미 착용" + ".png", frame)
        if not ret:
            break
        else:
            # imncode -> 이미지를 불러오는 함수
            im, buffer = cv2.imencode('.jpg', image_o)
            image_o = buffer.tobytes()
            yield (b'--image_o\r\n'
                   b'Content-Type: image/jpeg\r\n\r\n' + image_o + b'\r\n')  # concat frame one by one and show result



        for face in face_detector:

            # face wrapped with rectangle
            cv2.rectangle(image, (face.left(), face.top()), (face.right(), face.bottom()),
                          (0, 0, 255), 3)

            # make prediction and transform to numpy array
    #         landmarks = predictor(image, face)  # 얼굴에서 68개 점 찾기

    #         #create list to contain landmarks
    #         landmark_list = []

    #         # append (x, y) in landmark_list
    #         for p in landmarks.parts():
    #             landmark_list.append([p.x, p.y])
    #             cv2.circle(image, (p.x, p.y), 2, (0, 255, 0), -1)


        cv2.imshow('result', image)

        # wait for keyboard input
        key = cv2.waitKey(1)

        # if esc,
        if key == 27:
            vid_in.release()
            cv2.destroyAllWindows()
            break

    #vid_in.release()

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\smt051\anaconda3\envs\pj3\lib\site-packages (1.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\smt051\anaconda3\envs\pj3\lib\site-packages (from flask) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\smt051\anaconda3\envs\pj3\lib\site-packages (from flask) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\smt051\anaconda3\envs\pj3\lib\site-packages (from flask) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\smt051\anaconda3\envs\pj3\lib\site-packages (from flask) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\smt051\anaconda3\envs\pj3\lib\site-packages (from Jinja2>=2.10.1->flask) (1.1.1)

# %%
from flask import Flask, render_template, Response
import dlib
import cv2
import numpy as np
import os

 # create list for landmarks
ALL = list(range(0, 68))
RIGHT_EYEBROW = list(range(17, 22))
LEFT_EYEBROW = list(range(22, 27))
RIGHT_EYE = list(range(36, 42))
LEFT_EYE = list(range(42, 48))
NOSE = list(range(27, 36))
MOUTH_OUTLINE = list(range(48, 61))
MOUTH_INNER = list(range(61, 68))
JAWLINE = list(range(0, 17))
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')
        

try:
    os.mkdir("C:/Users/SMT051/Desktop/nonono")
except:
    print("이미 폴더가 있습니다.")
        # create VideoCapture object (input the video)
        # 0 for web camera
vid_in = cv2.VideoCapture(0)
        # "---" for the video file
        #vid_in = cv2.VideoCapture("baby_vid.mp4")

        # capture the image in an infinite loop
        # -> make it looks like a video
# Out:
# 이미 폴더가 있습니다.

# %%
        

#app <- 플라스크
app = Flask(__name__)

#camera <- 웹캠
  # use 0 for web camera
#  for cctv camera use rtsp://username:password@ip_address:554/user=username_password='password'_channel=channel_number_stream=0.sdp' instead of camera
# for local webcam use cv2.VideoCapture(0)
 camera = cv2.VideoCapture(0)
def gen_frames():
   # generate frame by frame from camera
    faceCheck = 0
    idx = 0
    co=0
    while True:
        
        
        



        # create face detector, predictor
        
        
        

            # Get frame from video
            
            ret, image_o = vid_in.read()

           # resize the video
            image = cv2.resize(image_o, dsize=(640, 480), interpolation=cv2.INTER_AREA)
            img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Get faces (up-sampling=1)
            face_detector = detector(img_gray, 1)
            # the number of face detected

            if len(face_detector) == 0:
                faceCheck = 0
            else:
                faceCheck += 1
        #    print("The number of faces detected : {}".format(len(face_detector)))

            # loop as the number of face
            # one loop belong to one face

            if faceCheck > 60:
                print("마스크 !!!!! !!!경고 !!!!!")
                faceCheck=0
                co += 1
                cv2.imwrite("C:/Users/SMT051/Desktop/nonono/{}.png".format(co),image_o)


                #cv2.imwrite("C:/Users/SMT051/Desktop/마스크 미 착용" + ".png", frame)
            for face in face_detector:

                # face wrapped with rectangle
                cv2.rectangle(image, (face.left(), face.top()), (face.right(), face.bottom()),
                              (0, 0, 255), 3)

                # make prediction and transform to numpy array
        #         landmarks = predictor(image, face)  # 얼굴에서 68개 점 찾기

        #         #create list to contain landmarks
        #         landmark_list = []

        #         # append (x, y) in landmark_list
        #         for p in landmarks.parts():
        #             landmark_list.append([p.x, p.y])
        #             cv2.circle(image, (p.x, p.y), 2, (0, 255, 0), -1)


            cv2.imshow('result', image)

            # wait for keyboard input
            key = cv2.waitKey(1)

            # if esc,
            if key == 27:
                vid_in.release()
                cv2.destroyAllWindows()
                break

            if not ret:
                break
            else:
                # imncode -> 이미지를 불러오는 함수
                ret, buffer = cv2.imencode('.jpg', frame)
                frame = buffer.tobytes()
                yield (b'--frame\r\n'
                       b'Content-Type: image/jpeg\r\n\r\n' + frame + b'\r\n')  # concat frame one by one and show result


@app.route('/video_feed')
def video_feed():
    #vid_in.release()
    #Video streaming route. Put this in the src attribute of an img tag
    return Response(gen_frames(),mimetype='multipart/x-mixed-replace; boundary=image_o')
    

    


@app.route('/')
def index():
    """Video streaming home page."""
    return render_template('index.html')


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
