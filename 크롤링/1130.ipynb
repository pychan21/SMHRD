# %% [markdown]
# ### 한솥 도시락의 이름 , 가격 정보 수집

# %%
from selenium import webdriver as wb
from bs4 import BeautifulSoup as bs
import pandas as pd
import time

# %%
url = "https://www.hsd.co.kr/menu/menu_list"

# %%
driver = wb.Chrome()
driver.get(url)

# %%
soup=bs(driver.page_source,'lxml')

# %%
# 5개 메뉴명 크롤링

# %%
menu = soup.select("h4.fz_03")

# %%
pay = soup.select("strong")

# %%
menu
# Out:
# [<h4 class="h fz_03">매화(치킨, 연어구이)</h4>,
#  <h4 class="h fz_03">매화 (순살 고등어 간장구이)</h4>,
#  <h4 class="h fz_03">진달래</h4>,
#  <h4 class="h fz_03">개나리(순살 고등어 간장구이)</h4>,
#  <h4 class="h fz_03">나시고랭</h4>]

# %%
btn_more = driver.find_element_by_class_name('c_05')

# %%
btn_more.click()

# %% [markdown]
# ### 예외처리 ( try문에서 오류가 나면 except로 빠짐)

# %%
try: 
    for i in range(30) :
        btn_more.click()
        time.sleep(2)
except:
    print(i)
# Out:
# 2

# %%
soup = bs(driver.page_source,'lxml')

# %%
menu = soup.select("h4.h.fz_03")

# %%
pay = soup.select("strong")

# %%
menu_list = []
pay_list = []

for i in range(len(menu)) :
    menu_list.append(menu[i].text.strip())
    pay_list.append(pay[i].text.strip())

# %%
pd.set_option('display.max_rows',200)

# %%
info = {'menu':menu_list,'pay':pay_list}

# %%
hansot = pd.DataFrame(info)

# %%
hansot
# Out:
#                  menu     pay
# 0        매화(치킨, 연어구이)  10,000
# 1    매화 (순살 고등어 간장구이)  10,000
# 2                 진달래   7,000
# 3    개나리(순살 고등어 간장구이)   8,000
# 4                나시고랭   4,500
# 5         생선까스도련님고기고기   5,500
# 6          돈까스도련님고기고기   5,500
# 7          탕수육도련님고기고기   5,600
# 8             새치 고기고기   6,000
# 9             돈치 고기고기   5,200
# 10               고기고기   4,000
# 11       칠리탕수육 육개장 정식   8,000
# 12         통치즈돈까스 도시락   5,800
# 13         주말숯불삼겹2종정식  15,000
# 14          고추장숯불삼겹정식   9,000
# 15             숯불삼겹정식   8,500
# 16         제육 김치찌개 정식   8,000
# 17           콤비네이션 정식   6,000
# 18             숯불직화구이   6,500
# 19               소불고기   5,000
# 20             메가치킨제육   6,900
# 21            생선까스도련님   3,900
# 22        칠리 찹쌀탕수육도련님   4,000
# 23                 동백   5,000
# 24               치킨제육   4,400
# 25                 국화   4,200
# 26             돈까스도련님   3,900
# 27               제육볶음   3,900
# 28          미니닭가슴살볶음밥   2,200
# 29                한솥밥   1,000
# ...
